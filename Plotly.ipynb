# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py
import seaborn as sns
import plotly.express as px
import cufflinks as cf
# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot #for running in jupyter notebook
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
arr_1 = np.random.rand(50,4)
df_1 = pd.DataFrame(arr_1, columns = ['A','B',"C",'D'])
df_1.head()
# Out:
#           A         B         C         D
# 0  0.301134  0.017934  0.956340  0.859348
# 1  0.325589  0.725820  0.905969  0.737053
# 2  0.960274  0.267758  0.637656  0.496870
# 3  0.501490  0.623685  0.857329  0.029481
# 4  0.976090  0.587971  0.344180  0.495938

# %% [markdown]
# ### Basic interactive plot

# %%
df_1.iplot()
# Out:
# <div>                            <div id="4dac284b-3c6f-4a6a-801d-388aebf87dd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
import plotly.graph_objects as go

# %% [markdown]
# # Line chart

# %%
dfStock = px.data.stocks()
px.line(dfStock, x='date', y='GOOG',labels={'x':'Date','y':'Price'})
# Out:
# <div>                            <div id="59767790-3af3-47f8-a06e-4f516f404632" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59767790-3af3-47f8-a06e-4f516f404632")) {                    Plotly.newPlot(                        "59767790-3af3-47f8-a06e-4f516f404632",                        [{"hovertemplate": "date=%{x}<br>GOOG=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2018-01-01", "2018-01-08", "2018-01-15", "2018-01-22", "2018-01-29", "2018-02-05", "2018-02-12", "2018-02-19", "2018-02-26", "2018-03-05", "2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-
# ...

# %% [markdown]
# ### Creating 2 line chart in same graph

# %%
px.line(dfStock,x='date', y=['GOOG','AAPL'], labels = {'x':'Date', 'y':'Price'}, title='Apple vs Google')
# Out:
# <div>                            <div id="6bb71532-4e69-4bd8-a1ce-275ea3719119" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6bb71532-4e69-4bd8-a1ce-275ea3719119")) {                    Plotly.newPlot(                        "6bb71532-4e69-4bd8-a1ce-275ea3719119",                        [{"hovertemplate": "variable=GOOG<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "GOOG", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "GOOG", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2018-01-01", "2018-01-08", "2018-01-15", "2018-01-22", "2018-01-29", "2018-02-05", "2018-02-12", "2018-02-19", "2018-02-26", "2018-03-05", "2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16"
# ...

# %% [markdown]
# ### 3 line charts with different line style

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=dfStock.date, y=dfStock.AAPL, mode='lines', name='Apple'))
fig.add_trace(go.Scatter(x=dfStock.date, y=dfStock.AMZN, mode='lines+markers', name='Amazon'))
fig.add_trace(go.Scatter(x=dfStock.date, y=dfStock.GOOG, mode='lines+markers', name='Google',
             line = dict(color='firebrick', width=2, dash='dashdot')))
# Out:
# <div>                            <div id="3c51d0f5-e29f-4959-8c56-86b149a6e2cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c51d0f5-e29f-4959-8c56-86b149a6e2cc")) {                    Plotly.newPlot(                        "3c51d0f5-e29f-4959-8c56-86b149a6e2cc",                        [{"mode": "lines", "name": "Apple", "type": "scatter", "x": ["2018-01-01", "2018-01-08", "2018-01-15", "2018-01-22", "2018-01-29", "2018-02-05", "2018-02-12", "2018-02-19", "2018-02-26", "2018-03-05", "2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "
# ...

# %% [markdown]
# ### Update layout of chart with titles and labels

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=dfStock.date, y=dfStock.AAPL, mode='lines', name='Apple'))
fig.add_trace(go.Scatter(x=dfStock.date, y=dfStock.AMZN, mode='lines+markers', name='Amazon'))
fig.add_trace(go.Scatter(x=dfStock.date, y=dfStock.GOOG, mode='lines+markers', name='Google',
             line = dict(color='firebrick', width=2, dash='dashdot')))
fig.update_layout(title='Stock Proce Data 2018-2020', xaxis_title='Price', yaxis_title='Date')
# Out:
# <div>                            <div id="cea13382-3e17-4094-90f5-abe2516202dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cea13382-3e17-4094-90f5-abe2516202dc")) {                    Plotly.newPlot(                        "cea13382-3e17-4094-90f5-abe2516202dc",                        [{"mode": "lines", "name": "Apple", "type": "scatter", "x": ["2018-01-01", "2018-01-08", "2018-01-15", "2018-01-22", "2018-01-29", "2018-02-05", "2018-02-12", "2018-02-19", "2018-02-26", "2018-03-05", "2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "
# ...

# %% [markdown]
# ### Advance customization in chart labels and layout

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=dfStock.date, y=dfStock.AAPL, mode='lines', name='Apple'))
fig.add_trace(go.Scatter(x=dfStock.date, y=dfStock.AMZN, mode='lines+markers', name='Amazon'))
fig.add_trace(go.Scatter(x=dfStock.date, y=dfStock.GOOG, mode='lines+markers', name='Google',
             line = dict(color='firebrick', width=2, dash='dashdot')))
fig.update_layout(
xaxis=dict(
showline=True, showgrid=False, showticklabels=True, linecolor='rgb(204,204,204)',
linewidth=2, ticks='outside', tickfont=dict(
family='Arial', size=12, color='rgb(82,82,82)',)
,
),
yaxis=dict(
showline=False, showgrid=False, showticklabels=False, zeroline=False),
autosize=False, 
margin=dict(
autoexpand=False, l=100, r=20, t=110,),
showlegend=False, plot_bgcolor='white')
# Out:
# <div>                            <div id="14ab12ac-6b88-4129-b0ee-54a996af9866" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14ab12ac-6b88-4129-b0ee-54a996af9866")) {                    Plotly.newPlot(                        "14ab12ac-6b88-4129-b0ee-54a996af9866",                        [{"mode": "lines", "name": "Apple", "type": "scatter", "x": ["2018-01-01", "2018-01-08", "2018-01-15", "2018-01-22", "2018-01-29", "2018-02-05", "2018-02-12", "2018-02-19", "2018-02-26", "2018-03-05", "2018-03-12", "2018-03-19", "2018-03-26", "2018-04-02", "2018-04-09", "2018-04-16", "2018-04-23", "2018-04-30", "2018-05-07", "2018-05-14", "2018-05-21", "2018-05-28", "2018-06-04", "2018-06-11", "2018-06-18", "2018-06-25", "2018-07-02", "2018-07-09", "2018-07-16", "
# ...

# %% [markdown]
# # Bar chart

# %%
dfUS = px.data.gapminder().query("country == 'United States'")
px.bar(dfUS, x='year', y='pop', )
# Out:
# <div>                            <div id="6c50d46d-727f-4ba9-9fd9-0fc6f5c180e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c50d46d-727f-4ba9-9fd9-0fc6f5c180e9")) {                    Plotly.newPlot(                        "6c50d46d-727f-4ba9-9fd9-0fc6f5c180e9",                        [{"alignmentgroup": "True", "hovertemplate": "year=%{x}<br>pop=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [157553000, 171984000, 186538000, 198712000, 209896000, 220239000, 232187835, 242803533, 256894189, 272911760, 287675526, 3
# ...
